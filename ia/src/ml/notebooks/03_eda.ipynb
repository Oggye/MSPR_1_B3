# %%
import pandas as pd

data = {
    "Critère": ["Prix", "AutoML", "Explicabilité", "Déploiement"],
    
    "Azure ML": [
        "Moyen à élevé (usage + compute)",
        "Oui (AutoML intégré)",
        "Bonne (SHAP, interpretabilité)",
        "Très complet (AKS, MLOps, API)"
    ],
    
    "SageMaker": [
        "Élevé mais flexible",
        "Oui (Autopilot)",
        "Très bonne (Clarify, bias detection)",
        "Excellent (prod industriel, endpoints)"
    ],
    
    "Vertex AI": [
        "Moyen (GPU/TPU compétitif)",
        "Oui (AutoML performant)",
        "Bonne (Explainable AI)",
        "Très bon (GCP natif, simple)"
    ],
    
    "Hugging Face AutoTrain": [
        "Faible à moyen",
        "Oui (très simple)",
        "Limitée",
        "Simple (Spaces, Hub, API)"
    ]
}

df = pd.DataFrame(data)

display(df)   # fonctionne dans Jupyter / VSCode notebook
# Out:
#          Critère                         Azure ML  \
# 0           Prix  Moyen à élevé (usage + compute)
# 1         AutoML             Oui (AutoML intégré)
# 2  Explicabilité   Bonne (SHAP, interpretabilité)
# 3    Déploiement   Très complet (AKS, MLOps, API)
#
#                                 SageMaker                     Vertex AI  \
# 0                     Élevé mais flexible    Moyen (GPU/TPU compétitif)
# 1                         Oui (Autopilot)       Oui (AutoML performant)
# 2    Très bonne (Clarify, bias detection)        Bonne (Explainable AI)
# 3  Excellent (prod industriel, endpoints)  Très bon (GCP natif, simple)
#
#       Hugging Face AutoTrain
# 0             Faible à moyen
# 1          Oui (très simple)
# 2                    Limitée
# 3  Simple (Spaces, Hub, API)
